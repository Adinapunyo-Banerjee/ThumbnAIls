# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
with open('/content/drive/MyDrive/Colab Notebooks/Youtube Project/channel_names.txt', 'r') as f:
    lines = f.readlines()

# %%
lines = list(set(lines))

# Open the same file for writing (this will clear the file)
with open('input_file.txt', 'w') as f:
    # Write the cleaned content back to the file
    for line in lines:
        f.write(line)
